# %% [raw]
# Importing Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score, KFold
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB

# %% [markdown]
# Collecting Data

# %%
df=pd.read_csv('winequality-red.csv')
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 4         9.4        5
# ...       ...      ...
# 1594     10.5        5
# 1595     11.2        6
# 1596     11.0        6
# 1597     10.2        5
# 1598     11.0        6
#
# [1599 rows x 12 columns]

# %% [markdown]
# Data Information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %% [markdown]
# Attribute Information

# %% [raw]
# fixed acidity	           Most acids involved with wine or fixed or nonvolatile
# volatile acidity	       The amount of acetic acid in wine
# citric acid	               The amount of citric acid in wine
# residual sugar	           The amount of sugar remaining after fermentation stops
# chlorides	               The amount of salt in the wine.
# free sulfur dioxide	       The amount of free sulfur dioxide in the wine
# total sulfur dioxide	   Amount of free and bound forms of SO2
# density	                   The measurement of how tightly a material is packed together
# PH	                       Describes how acidic or basic a wine is on a scale from 0 (very acidic) to 14 (very basic); most wines are between 3-4
# Alcohol	                   The percent alcohol content of the wine
# quality	                   Output variable (based on sensory data, score between 3 and 8)

# %% [markdown]
# Missing Values Handling

# %%
df.isna().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# Visualization and Plots

# %%
# Rename columns to better recall them.
df.rename(columns = {"fixed acidity": "fixed_acidity",
                       "volatile acidity": "volatile_acidity",
                       "citric acid": "citric_acid",
                       "residual sugar": "residual_sugar",
                       "chlorides": "chlorides",
                       "free sulfur dioxide": "free_sulfur_dioxide",
                       "total sulfur dioxide": "total_sulfur_dioxide"},
            inplace = True)

# %%
# Create a list of DataFrame columns
columns = list(df.columns)

# %%
fig, ax = plt.subplots(11, 1, figsize=(10,45))
for i in range(11) :
    sns.boxplot(x=columns[i], data=df, ax=ax[i])

# %%
corr = df.corr()
# cmap = sns.diverging_palette(-1, 1, s=100, l=50, n=15, center="dark", as_cmap=True)
plt.figure(figsize=(9, 6))
sns.heatmap(corr, annot=True, fmt='.2f', linewidth=0.5, cmap='Purples', mask=np.triu(corr))
plt.show()

# %% [markdown]
# Plots Analysis

# %% [raw]
# Best Correlations are between :
# citeic_acid & flex_acidity ---> 0.67
# density & flex_acidity ---> 0.67
# total_sulfor_dioxide & free_sulfor_dioxide ---> 0.67

# %% [markdown]
# Target Categorizing

# %%
# Quality classes :
df.quality.unique()
# Out:
# array([5, 6, 7, 4, 8, 3], dtype=int64)

# %% [raw]
# Replace values in quality column to Good and Middle and Bad

# %%
data = df.replace({'quality' : {
                                    8 : 'Good',
                                    7 : 'Good',
                                    6 : 'Middle',
                                    5 : 'Middle',
                                    4 : 'Bad',
                                    3 : 'Bad',
        }}
)

# %%
df.head()
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %% [markdown]
# Normalization

# %%
# Create X from DataFrame and y as Target
X_temp = data.drop(columns='quality')
y = data.quality

# %% [raw]
# Normalize X data to decrease effect of larg number.
# Here, Using MinMaxScaler and ranged in [0, 1]

# %%
scaler = MinMaxScaler(feature_range=(0, 1)).fit_transform(X_temp)
X = pd.DataFrame(scaler, columns=X_temp.columns)
X.describe().T.style.background_gradient(axis=0, cmap='Purples')
# Out:
# <style type="text/css">
# #T_b5cdd_row0_col0, #T_b5cdd_row0_col3, #T_b5cdd_row1_col0, #T_b5cdd_row1_col3, #T_b5cdd_row1_col7, #T_b5cdd_row2_col0, #T_b5cdd_row2_col3, #T_b5cdd_row3_col0, #T_b5cdd_row3_col1, #T_b5cdd_row3_col3, #T_b5cdd_row3_col5, #T_b5cdd_row3_col6, #T_b5cdd_row4_col0, #T_b5cdd_row4_col2, #T_b5cdd_row4_col3, #T_b5cdd_row4_col7, #T_b5cdd_row5_col0, #T_b5cdd_row5_col3, #T_b5cdd_row6_col0, #T_b5cdd_row6_col3, #T_b5cdd_row6_col4, #T_b5cdd_row6_col7, #T_b5cdd_row7_col0, #T_b5cdd_row7_col3, #T_b5cdd_row8_col0, #T_b5cdd_row8_col3, #T_b5cdd_row9_col0, #T_b5cdd_row9_col3, #T_b5cdd_row10_col0, #T_b5cdd_row10_col3 {
#   background-color: #fcfbfd;
#   color: #000000;
# }
# #T_b5cdd_row0_col1 {
#   background-color: #8d89c0;
#   color: #f1f1f1;
# }
# #T_b5cdd_row0_col2 {
#   background-color: #7b74b5;
#   color: #f1f1f1;
# }
# #T_b5cdd_row0_col4 {
#   background-color: #a5a2cd;
#   color: #f1f1f1;
# }
# #T_b5cdd_row0_col5 {
#   background-color: #9d99c7;
#   color: #f1f1f1;
# }
# #T_b5cdd_row0_col6 {
#   background-color: #7d77b7;
#   color: #f1f1f1;
# }
# #T_b5cdd_row0_col7, #T_b5cdd_row2_col7, #T_b5cdd_row3_col7, #T_b5cdd_row5_col7, #T_b5cdd_row7_col7, #T_b5cdd_row8_col7, #T_b5cdd_row9_col7 {
#   background-color: #c6c7e1;
#   color: #000000;
# }
# #T_b5cdd_row1_col1 {
#   background-color: #acaad1;
#   color: #000000;
# }
# #T_b5cdd_row1_col2 {
#   background-color: #bbbbdb;
#   color: #000000;
# }
# #T_b5cdd_row1_col4, #T_b5cdd_row8_col2 {
#   background-color: #bebedd;
#   color: #000000;
# }
# #T_b5cdd_row1_col5 {
#   background-color: #a8a6cf;
#   color: #f1f1f1;
# }
# #T_b5cdd_row1_col6 {
#   background-color: #9793c5;
#   color: #f1f1f1;
# }
# #T_b5cdd_row2_col1 {
#   background-color: #b1b1d5;
#   color: #000000;
# }
# #T_b5cdd_row2_col2, #T_b5cdd_row7_col1, #T_b5cdd_row7_col4, #T_b5cdd_row7_col5, #T_b5cdd_row7_col6, #T_b5cdd_row10_col7 {
#   background-color: #3f007d;
#   color: #f1f1f1;
# }
# #T_b5cdd_row2_col4 {
#   background-color: #f2f0f7;
#   color: #000000;
# }
# #T_b5cdd_row2_col5 {
#   background-color: #afaed4;
#   color: #000000;
# }
# #T_b5cdd_row2_col6 {
#   background-color: #786db2;
#   color: #f1f1f1;
# }
# #T_b5cdd_row3_col2 {
#   background-color: #eae9f3;
#   color: #000000;
# }
# #T_b5cdd_row3_col4 {
#   background-color: #f9f7fb;
#   color: #000000;
# }
# #T_b5cdd_row4_col1 {
#   background-color: #f8f7fb;
#   color: #000000;
# }
# #T_b5cdd_row4_col4 {
#   background-color: #f0eef6;
#   color: #000000;
# }
# #T_b5cdd_row4_col5 {
#   background-color: #f6f5f9;
#   color: #000000;
# }
# #T_b5cdd_row4_col6 {
#   background-color: #f9f8fb;
#   color: #000000;
# }
# #T_b5cdd_row5_col1 {
#   background-color: #d9d9ea;
#   color: #000000;
# }
# #T_b5cdd_row5_col2 {
#   background-color: #8885be;
#   color: #f1f1f1;
# }
# #T_b5cdd_row5_col4, #T_b5cdd_row6_col1 {
#   background-color: #f4f2f8;
#   color: #000000;
# }
# #T_b5cdd_row5_col5 {
#   background-color: #ddddec;
#   color: #000000;
# }
# #T_b5cdd_row5_col6 {
#   background-color: #bebfdd;
#   color: #000000;
# }
# #T_b5cdd_row6_col2, #T_b5cdd_row10_col4 {
#   background-color: #c9c9e2;
#   color: #000000;
# }
# #T_b5cdd_row6_col5 {
#   background-color: #f6f4f9;
#   color: #000000;
# }
# #T_b5cdd_row6_col6 {
#   background-color: #e6e5f1;
#   color: #000000;
# }
# #T_b5cdd_row7_col2 {
#   background-color: #9a96c6;
#   color: #f1f1f1;
# }
# #T_b5cdd_row8_col1 {
#   background-color: #51218c;
#   color: #f1f1f1;
# }
# #T_b5cdd_row8_col4, #T_b5cdd_row8_col5 {
#   background-color: #50208c;
#   color: #f1f1f1;
# }
# #T_b5cdd_row8_col6 {
#   background-color: #51228d;
#   color: #f1f1f1;
# }
# #T_b5cdd_row9_col1 {
#   background-color: #dedeed;
#   color: #000000;
# }
# #T_b5cdd_row9_col2 {
#   background-color: #e3e2ef;
#   color: #000000;
# }
# #T_b5cdd_row9_col4 {
#   background-color: #e0dfee;
#   color: #000000;
# }
# #T_b5cdd_row9_col5 {
#   background-color: #e1e0ee;
#   color: #000000;
# }
# #T_b5cdd_row9_col6 {
#   background-color: #d5d5e9;
#   color: #000000;
# }
# #T_b5cdd_row10_col1 {
#   background-color: #9894c5;
#   color: #f1f1f1;
# }
# #T_b5cdd_row10_col2 {
#   background-color: #6c55a5;
#   color: #f1f1f1;
# }
# #T_b5cdd_row10_col5 {
#   background-color: #a6a3cd;
#   color: #f1f1f1;
# }
# #T_b5cdd_row10_col6 {
#   background-color: #7a71b4;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_b5cdd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b5cdd_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_b5cdd_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_b5cdd_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_b5cdd_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_b5cdd_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_b5cdd_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_b5cdd_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_b5cdd_level0_col7" class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b5cdd_level0_row0" class="row_heading level0 row0" >fixed_acidity</th>
#       <td id="T_b5cdd_row0_col0" class="data row0 col0" >1599.000000</td>
#       <td id="T_b5cdd_row0_col1" class="data row0 col1" >0.329171</td>
#       <td id="T_b5cdd_row0_col2" class="data row0 col2" >0.154079</td>
#       <td id="T_b5cdd_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_b5cdd_row0_col4" class="data row0 col4" >0.221239</td>
#       <td id="T_b5cdd_row0_col5" class="data row0 col5" >0.292035</td>
#       <td id="T_b5cdd_row0_col6" class="data row0 col6" >0.407080</td>
#       <td id="T_b5cdd_row0_col7" class="data row0 col7" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b5cdd_level0_row1" class="row_heading level0 row1" >volatile_acidity</th>
#       <td id="T_b5cdd_row1_col0" class="data row1 col0" >1599.000000</td>
#       <td id="T_b5cdd_row1_col1" class="data row1 col1" >0.279329</td>
#       <td id="T_b5cdd_row1_col2" class="data row1 col2" >0.122644</td>
#       <td id="T_b5cdd_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_b5cdd_row1_col4" class="data row1 col4" >0.184932</td>
#       <td id="T_b5cdd_row1_col5" class="data row1 col5" >0.273973</td>
#       <td id="T_b5cdd_row1_col6" class="data row1 col6" >0.356164</td>
#       <td id="T_b5cdd_row1_col7" class="data row1 col7" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b5cdd_level0_row2" class="row_heading level0 row2" >citric_acid</th>
#       <td id="T_b5cdd_row2_col0" class="data row2 col0" >1599.000000</td>
#       <td id="T_b5cdd_row2_col1" class="data row2 col1" >0.270976</td>
#       <td id="T_b5cdd_row2_col2" class="data row2 col2" >0.194801</td>
#       <td id="T_b5cdd_row2_col3" class="data row2 col3" >0.000000</td>
#       <td id="T_b5cdd_row2_col4" class="data row2 col4" >0.090000</td>
#       <td id="T_b5cdd_row2_col5" class="data row2 col5" >0.260000</td>
#       <td id="T_b5cdd_row2_col6" class="data row2 col6" >0.420000</td>
#       <td id="T_b5cdd_row2_col7" class="data row2 col7" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b5cdd_level0_row3" class="row_heading level0 row3" >residual_sugar</th>
#       <td id="T_b5cdd_row3_col0" class="data row3 col0" >1599.000000</td>
#       <td id="T_b5cdd_row3_col1" class="data row3 col1" >0.112247</td>
#       <td id="T_b5cdd_row3_col2" class="data row3 col2" >0.096570</td>
#       <td id="T_b5cdd_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_b5cdd_row3_col4" class="data row3 col4" >0.068493</td>
#       <td id="T_b5cdd_row3_col5" class="data row3 col5" >0.089041</td>
#       <td id="T_b5cdd_row3_col6" class="data row3 col6" >0.116438</td>
#       <td id="T_b5cdd_row3_col7" class="data row3 col7" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b5cdd_level0_row4" class="row_heading level0 row4" >chlorides</th>
#       <td id="T_b5cdd_row4_col0" class="data row4 col0" >1599.000000</td>
#       <td id="T_b5cdd_row4_col1" class="data row4 col1" >0.125988</td>
#       <td id="T_b5cdd_row4_col2" class="data row4 col2" >0.078573</td>
#       <td id="T_b5cdd_row4_col3" class="data row4 col3" >0.000000</td>
#       <td id="T_b5cdd_row4_col4" class="data row4 col4" >0.096828</td>
#       <td id="T_b5cdd_row4_col5" class="data row4 col5" >0.111853</td>
#       <td id="T_b5cdd_row4_col6" c

# %% [markdown]
#  Initialization

# %%
# define a function to ploting Confusion matrix
def plot_confusion_matrix(y_test, y_prediction):
    '''Plotting Confusion Matrix'''
    cm = metrics.confusion_matrix(y_test, y_prediction)
    ax = plt.subplot()
    ax = sns.heatmap(cm, annot=True, fmt='', cmap="Purples")
    ax.set_xlabel('Prediced labels', fontsize=18)
    ax.set_ylabel('True labels', fontsize=18)
    ax.set_title('Confusion Matrix', fontsize=25)
    ax.xaxis.set_ticklabels(['Bad', 'Good', 'Middle'])
    ax.yaxis.set_ticklabels(['Bad', 'Good', 'Middle']) 
    plt.show()

# %%
# define a function to ploting Classification report
def clfr_plot(y_test, y_pred) :
    ''' Plotting Classification report'''
    cr = pd.DataFrame(metrics.classification_report(y_test, y_pred_rf, digits=3,
                                            output_dict=True)).T
    cr.drop(columns='support', inplace=True)
    sns.heatmap(cr, cmap='Purples', annot=True, linecolor='white', linewidths=0.5).xaxis.tick_top()

# %%
def clf_plot(y_pred) :
    '''
    1) Ploting Confusion Matrix
    2) Plotting Classification Report'''
    cm = metrics.confusion_matrix(y_test, y_pred)
    cr = pd.DataFrame(metrics.classification_report(y_test, y_pred, digits=3, output_dict=True)).T
    cr.drop(columns='support', inplace=True)
    
    fig, ax = plt.subplots(1, 2, figsize=(15, 5))
    
    # Left AX : Confusion Matrix
    ax[0] = sns.heatmap(cm, annot=True, fmt='', cmap="Purples", ax=ax[0])
    ax[0].set_xlabel('Prediced labels', fontsize=18)
    ax[0].set_ylabel('True labels', fontsize=18)
    ax[0].set_title('Confusion Matrix', fontsize=25)
    ax[0].xaxis.set_ticklabels(['Bad', 'Good', 'Middle'])
    ax[0].yaxis.set_ticklabels(['Bad', 'Good', 'Middle'])
    
    # Right AX : Classification Report
    ax[1] = sns.heatmap(cr, cmap='Purples', annot=True, linecolor='white', linewidths=0.5, ax=ax[1])
    ax[1].xaxis.tick_top()
    ax[1].set_title('Classification Report', fontsize=25)
    plt.show()

# %%
data.quality.value_counts()
# Out:
# quality
# Middle    1319
# Good       217
# Bad         63
# Name: count, dtype: int64

# %%
# Splite Dataframe
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)

# %% [markdown]
# RandomForestClassifier

# %%
# a dictionary to define parameters to test in algorithm
parameters = {
    'n_estimators' : [50, 150, 500],
    'criterion' : ['gini', 'entropy', 'log_loss'],
    'max_features' : ['sqrt', 'log2']
}

rf = RandomForestClassifier(n_jobs=-1)
rf_cv = GridSearchCV(estimator=rf, cv=20, param_grid=parameters).fit(X_train, y_train)

print('Tuned hyper parameters : ', rf_cv.best_params_)
print('accuracy : ', rf_cv.best_score_)
# Out:
# Tuned hyper parameters :  {'criterion': 'gini', 'max_features': 'sqrt', 'n_estimators': 150}
# accuracy :  0.8723870056497176

# %%
# Model :
rf = RandomForestClassifier(**rf_cv.best_params_).fit(X_train, y_train)

# %%
y_pred_rf = rf.predict(X_test)

rf_score = round(rf.score(X_test, y_test), 3)
print('RandomForestClassifier score : ', rf_score)
# Out:
# RandomForestClassifier score :  0.888

# %%
y_test.value_counts()
# Out:
# quality
# Middle    339
# Good       45
# Bad        16
# Name: count, dtype: int64

# %%
clf_plot(y_pred_rf)

# %% [markdown]
# LogisticRegression

# %%
# a dictionary to define parameters to test in algorithm
parameters = {
    'C' : [0.001, 0.01, 0.1, 1.0, 10, 100, 1000],
    'class_weight' : ['balanced'],
    'solver' : ['lbfgs', 'liblinear', 'newton-cg', 'newton-cholesky', 'sag', 'saga']
}

lr = LogisticRegression()
lr_cv = GridSearchCV(estimator=lr, param_grid=parameters, cv=10).fit(X_train, y_train)

print('Tuned hyper parameters : ', lr_cv.best_params_)
print('accuracy : ', lr_cv.best_score_)
# Out:
# Tuned hyper parameters :  {'C': 0.1, 'class_weight': 'balanced', 'solver': 'liblinear'}
# accuracy :  0.82484593837535

# %%
lr = LogisticRegression(**lr_cv.best_params_).fit(X_train, y_train)

# %%
y_pred_lr = lr.predict(X_test)

lr_score = round(lr.score(X_test, y_test), 3)
print('LogisticRegression score : ', lr_score)
# Out:
# LogisticRegression score :  0.85

# %%
clf_plot(y_pred_lr)

# %% [markdown]
#  SVC

# %%
# a dictionary to define parameters to test in algorithm
parameters = {
    'C' : [0.001, 0.01, 0.1, 1.0, 10, 100, 1000],
    'gamma' : [0.001, 0.01, 0.1, 1.0, 10, 100, 1000],
}



svc = SVC()
svc_cv = GridSearchCV(estimator=svc, param_grid=parameters, cv=10).fit(X_train, y_train)



print('Tuned hyper parameters : ', svc_cv.best_params_)
print('accuracy : ', svc_cv.best_score_)
# Out:
# Tuned hyper parameters :  {'C': 10, 'gamma': 100}
# accuracy :  0.8532212885154061

# %%
# Model
svc = SVC(**svc_cv.best_params_).fit(X_train, y_train)

# %%
y_pred_svc = svc.predict(X_test)

svc_score = round(svc.score(X_test, y_test), 3)
print('SVC Score : ', svc_score)
# Out:
# SVC Score :  0.888

# %%
clf_plot(y_pred_svc)

# %% [markdown]
#  DecisionTreeClassifier

# %%
# a dictionary to define parameters to test in algorithm
parameters = {
    'criterion' : ['gini', 'entropy', 'log_loss'],
    'splitter' : ['best', 'random'],
    'max_depth' : list(np.arange(4, 30, 1))
        }



tree = DecisionTreeClassifier()
tree_cv = GridSearchCV(estimator=tree, cv=10, param_grid=parameters).fit(X_train, y_train)



print('Tuned hyper parameters : ', tree_cv.best_params_)
print('accuracy : ', tree_cv.best_score_)
# Out:
# Tuned hyper parameters :  {'criterion': 'gini', 'max_depth': 7, 'splitter': 'best'}
# accuracy :  0.8348949579831932

# %%
tree = DecisionTreeClassifier(**tree_cv.best_params_).fit(X_train, y_train)

# %%
y_pred_tree = tree.predict(X_test)

tree_score = round(tree.score(X_test, y_test), 3)
print('DecisionTreeClassifier Score : ', tree_score)
# Out:
# DecisionTreeClassifier Score :  0.812

# %%
clf_plot(y_pred_tree)

# %% [markdown]
# KNeighborsClassifier

# %%
# a dictionary to define parameters to test in algorithm
parameters = {
    'n_neighbors' : list(np.arange(3, 50, 2)),
    'weights': ['uniform', 'distance'],
    'p' : [1, 2, 3, 4]
}

knn = KNeighborsClassifier()
knn_cv = GridSearchCV(estimator=knn, cv=10, param_grid=parameters).fit(X_train, y_train)

print('Tuned hyper parameters : ', knn_cv.best_params_)
print('accuracy : ', knn_cv.best_score_)
# Out:
# Tuned hyper parameters :  {'n_neighbors': 11, 'p': 1, 'weights': 'distance'}
# accuracy :  0.8615616246498599

# %%
knn = KNeighborsClassifier(**knn_cv.best_params_).fit(X_train, y_train)

# %%
y_pred_knn = knn_cv.predict(X_test)

knn_score = round(knn.score(X_test, y_test), 3)
print('KNeighborsClassifier Score :', knn_score)
# Out:
# KNeighborsClassifier Score : 0.855

# %%
clf_plot(y_pred_knn)

# %% [markdown]
# GaussianNB

# %%
gnb = GaussianNB().fit(X_train, y_train)
y_pred_gnb = gnb.predict(X_test)
gnb_score = round(gnb.score(X_test, y_test), 3)
print('GNB Score :', gnb_score)
# Out:
# GNB Score : 0.762

# %%
clf_plot(y_pred_gnb)

# %% [markdown]
#  Result

# %%
result = pd.DataFrame({
    'Algorithm' : ['RandomForestClassifier', 'LogisticRegression', 'SVC', 'DecisionTreeClassifier', 'KNeighborsClassifier', 'GaussianNB'],
    'Score' : [rf_score, lr_score, svc_score, tree_score, knn_score, gnb_score]
})

result.sort_values(by='Score', inplace=True)

# %%
sns.set_palette("Purples")

# %%
fig, ax = plt.subplots(1, 1, figsize=(15, 5))

sns.barplot(x='Algorithm', y='Score', data=result)
ax.bar_label(ax.containers[0], fmt='%.3f')
ax.set_xticklabels(labels=result.Algorithm, rotation=300)
plt.show()

# %% [raw]
# Results :
# Acording to the above plots, best algorithm base on Score is :SVC
# So, We choose SVC

# %%
# Model
svc = SVC(**svc_cv.best_params_)

# %%
svc.fit(X, y)
# Out:
# SVC(C=10, gamma=100)
